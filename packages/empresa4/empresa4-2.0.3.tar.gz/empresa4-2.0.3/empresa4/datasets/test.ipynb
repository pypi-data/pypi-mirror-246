# %%
import pandas as pd

# %%
df = pd.read_csv('./tb_sellout_02_productos_todos.csv')

# %%
df[df["product_id"] == 20001][["periodo", "product_id", "tn"]]
# Out:
#        periodo  product_id          tn
# 0       201701       20001   934.77222
# 785     201702       20001   798.01620
# 1566    201703       20001  1303.35771
# 2352    201704       20001  1069.96130
# 3136    201705       20001  1502.20132
# 3942    201706       20001  1520.06539
# 4765    201707       20001  1030.67391
# 5591    201708       20001  1267.39462
# 6438    201709       20001  1316.94604
# 7267    201710       20001  1439.75563
# 8116    201711       20001  1580.47401
# 8976    201712       20001  1049.38860
# 9832    201801       20001  1169.07532
# 10686   201802       20001  1043.76470
# 11534   201803       20001  1856.83534
# 12387   201804       20001  1251.28462
# 13241   201805       20001  1293.89788
# 14105   201806       20001  1150.79169
# 14956   201807       20001  1470.41009
# 15802   201808       20001  1800.96168
# 16650   201809       20001  1438.67455
# 17525   201810       20001  2295.19832
# 18422   201811       20001  1813.01511
# 19320   201812       20001  1486.68669
# 20212   201901       20001  1275.77351
# 21099   201902       20001  1259.09363
# 21993   201903       20001  1470.65653
# 22888   201904       20001  1647.63848
# 23807   201905       20001  1629.78233
# 24718   201906       20001  1109.93769
# 25634   201907       20001  1678.99318
# 26566   201908       20001  1261.34529
# 27495   201909       20001  1660.00561
# 28425   201910       20001  1561.50552
# 29377   201911       20001  1397.37231
# 30316   201912       20001  1504.68856

# %%
time_series_df = pd.read_csv('time_series_dataset.csv', index_col=[0,1])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/gero/Documents/Austral/Laboratorio de Implementación 3/empresa4/empresa4/datasets/test.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/home/gero/Documents/Austral/Laboratorio%20de%20Implementaci%C3%B3n%203/empresa4/empresa4/datasets/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> time_series_df = pd.read_csv('time_series_dataset.csv', index_col=[0,1])
#
# File ~/Documents/Austral/Laboratorio de Implementación 3/empresa4/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/Austral/Laboratorio de Implementación 3/empresa4/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/Documents/Austral/Laboratorio de Implementación 3/empresa4/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/Austral/Laboratorio de Implementación 3/empresa4/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/Documents/Austral/Laboratorio de Implementación 3/empresa4/venv/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'time_series_dataset.csv'

# %%
time_series_df = pd.read_csv('time_series_dataset.csv', index_col=[0,1])

# %%
import numpy as np
import time
from dtaidistance import dtw

def calculate_dtw_batch(time_series_batch, all_time_series):
    # Code as previously described...

# Sample a subset of your data
sample_size = 1000
sample_time_series = time_series[:sample_size]  # Assuming 'time_series' is your full dataset

# Time the computation for the sample
start_time = time.time()
sample_distances = calculate_dtw_batch(sample_time_series, sample_time_series)
end_time = time.time()
time_for_sample = end_time - start_time

# Number of comparisons for the sample and the full dataset
num_comparisons_sample = sample_size * (sample_size - 1) / 2
num_comparisons_full = 100000 * (100000 - 1) / 2

# Extrapolate to estimate total time
estimated_total_time = time_for_sample / num_comparisons_sample * num_comparisons_full

print(f"Time taken for sample: {time_for_sample} seconds")
print(f"Estimated total time: {estimated_total_time} seconds")
